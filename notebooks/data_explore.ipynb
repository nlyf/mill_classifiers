# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
data_cancer = datasets.load_breast_cancer()

# %%
df_cancer = pd.DataFrame(data_cancer.data,columns=data_cancer.feature_names)
df_cancer['y'] = data_cancer.target
# df_cancer['y_name'] = df_cancer.y.apply(lambda x: data_cancer.target_names[0] if x==0 else data_cancer.target_names[1] )
df_cancer.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension ...  worst texture  worst perimeter  worst area  \
# ...

# %%
for i in range(len(df_cancer.columns) - 1):
    g = sns.FacetGrid(df_cancer, col="y")
    g.map(plt.hist, df_cancer.columns[i]);
# Out:
# D:\MyProgramFiles\Anaconda3\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
df = pd.read_csv('../data/accuracy.csv',index_col=0).sort_values(by='acc',ascending=False)
df
# Out:
#          acc               name
# 5   0.964912      Random Forest
# 7   0.956140           AdaBoost
# 9   0.956140                QDA
# 4   0.947368      Decision Tree
# 10  0.938596              GOBIM
# 1   0.929825         Linear SVM
# 8   0.929825        Naive Bayes
# 3   0.921053   Gaussian Process
# 0   0.912281  Nearest Neighbors
# 2   0.587719            RBF SVM
# 6   0.473684         Neural Net
